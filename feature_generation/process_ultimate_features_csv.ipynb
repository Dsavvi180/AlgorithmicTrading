# %% [markdown]
# ### Converting 16gb ultimate features set csv to parquet format for more efficient data loading, processing and streaming to model for training.

# %%
import pandas as pd

# %%
df_features = pd.read_parquet('ultimate_feature_set.parquet')
list(zip(df_features.columns, df_features.isnull().sum()))
# Out:
# [('open_z100', 0),
#  ('high_z100', 0),
#  ('low_z100', 0),
#  ('close_z100', 0),
#  ('ret_1', 0),
#  ('ret_1_log', 0),
#  ('ret_1_z20', 0),
#  ('ret_1_z60', 0),
#  ('ret_1_z120', 0),
#  ('ret_1_z240', 0),
#  ('ret_1_z360', 0),
#  ('ret_1_z720', 0),
#  ('ret_1_vol20', 0),
#  ('ret_1_vol60', 0),
#  ('ret_1_vol120', 0),
#  ('ret_1_vol240', 0),
#  ('ret_1_vol360', 0),
#  ('ret_1_vol720', 0),
#  ('ret_1_log_vol20', 0),
#  ('ret_1_log_vol60', 0),
#  ('ret_1_log_vol120', 0),
#  ('ret_1_log_vol240', 0),
#  ('ret_1_log_vol360', 0),
#  ('ret_1_log_vol720', 0),
#  ('ret_1_log_z20', 0),
#  ('ret_1_log_z60', 0),
#  ('ret_1_log_z120', 0),
#  ('ret_1_log_z240', 0),
#  ('ret_1_log_z360', 0),
#  ('ret_1_log_z720', 0),
#  ('ret_k5', 0),
#  ('ret_k15', 0),
#  ('ret_k30', 0),
#  ('ret_k60', 0),
#  ('ret_k120', 0),
#  ('ret_k240', 0),
#  ('ret_k360', 0),
#  ('ret_k720', 0),
#  ('ret_k5_log', 0),
#  ('ret_k15_log', 0),
#  ('ret_k30_log', 0),
#  ('ret_k60_log', 0),
#  ('ret_k120_log', 0),
# ...

# %%
df_features
# Out:
#                            open_z100  high_z100  low_z100  close_z100  \
# timestamp
# 2020-07-20 00:00:00+00:00  -1.605258  -1.515217 -1.470574   -1.390984
# 2020-07-20 00:01:00+00:00  -1.605258  -1.515217 -1.470574   -1.390984
# 2020-07-20 00:02:00+00:00  -1.605258  -1.515217 -1.470574   -1.390984
# 2020-07-20 00:03:00+00:00  -1.605258  -1.515217 -1.470574   -1.390984
# 2020-07-20 00:04:00+00:00  -1.605258  -1.515217 -1.470574   -1.390984
# ...                              ...        ...       ...         ...
# 2025-07-17 23:55:00+00:00   1.930586   1.686210  1.868767    1.702777
# 2025-07-17 23:56:00+00:00   1.735302   1.590203  1.763280    1.634203
# 2025-07-17 23:57:00+00:00   1.664696   1.765282  1.774547    1.976756
# 2025-07-17 23:58:00+00:00   2.006875   2.183181  2.111719    2.207281
# 2025-07-17 23:59:00+00:00   2.157564   2.085446  1.990559    1.795882
#
#                               ret_1  ret_1_log  ret_1_z20  ret_1_z60  \
# timestamp
# ...

# %%
list(df_features.columns)
# Out:
# ['open_z100',
#  'high_z100',
#  'low_z100',
#  'close_z100',
#  'ret_1',
#  'ret_1_log',
#  'ret_1_z20',
#  'ret_1_z60',
#  'ret_1_z120',
#  'ret_1_z240',
#  'ret_1_z360',
#  'ret_1_z720',
#  'ret_1_vol20',
#  'ret_1_vol60',
#  'ret_1_vol120',
#  'ret_1_vol240',
#  'ret_1_vol360',
#  'ret_1_vol720',
#  'ret_1_log_vol20',
#  'ret_1_log_vol60',
#  'ret_1_log_vol120',
#  'ret_1_log_vol240',
#  'ret_1_log_vol360',
#  'ret_1_log_vol720',
#  'ret_1_log_z20',
#  'ret_1_log_z60',
#  'ret_1_log_z120',
#  'ret_1_log_z240',
#  'ret_1_log_z360',
#  'ret_1_log_z720',
#  'ret_k5',
#  'ret_k15',
#  'ret_k30',
#  'ret_k60',
#  'ret_k120',
#  'ret_k240',
#  'ret_k360',
#  'ret_k720',
#  'ret_k5_log',
#  'ret_k15_log',
#  'ret_k30_log',
#  'ret_k60_log',
#  'ret_k120_log',
#  'ret_k240_log',
#  'ret_k360_log',
#  'ret_k720_log',
#  'ret_k5_vol',
#  'ret_k15_vol',
#  'ret_k30_vol',
#  'ret_k60_vol',
#  'ret_k120_vol',
#  'ret_k240_vol',
#  'ret_k360_vol',
#  'ret_k720_vol',
#  'ret_k5_log_vol',
# ...
